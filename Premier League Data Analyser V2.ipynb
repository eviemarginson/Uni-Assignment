# %% [markdown]
# Premier League Data Analyser by Student 469104
#
# Prerequisites
# - Installed Python
# - Installed Pandas
# - Installed Colorama
# - Installed Pandas Openpyxl Tabulate
# - Installed Zip Tools Extension
# - Installed  Office Viewer Extension

# %%
# This script appends new data to an existing Excel file containing football club stats for Luton from the 23/24 Premier league season.

import pandas as pd

import os

# Existing Excel file
file_path = r"C:\Users\eviem\OneDrive\Documents\Uni\Module 2- Digital Maths and Programming\Uni-Assignment\Uni-Assignment\Football Club Stats.zip_unzipped\Football Club Stats\Luton Stats.xlsx"

# New data to append
new_data = pd.DataFrame({
    'Season': ['23/24'],
    'Team': ['Luton'],
    'Table Position': [18],
    'Points': [26],
    'Matches Played': [38],
    'Wins': [6],
    'Losses': [24],
    'Draws': [8],
    'Goals For': [52],
    'Goals Against': [85],
    'Goal Difference': [-33],
    'Top Scorer': ['Carlton Morris'],
    'Red Cards': [0],
    'Yellow Cards': [71]})

# Read the existing Excel file
df_existing = pd.read_excel(file_path)

# Append the new data to the existing DataFrame
df_new = pd.DataFrame(new_data)
df_combined = pd.concat([df_existing, df_new], ignore_index=True)

# Write the updated DataFrame back to the Excel file
df_combined.to_excel(file_path, index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 26
#       9 new_data = pd.DataFrame({
#      10     'Season': ['23/24'],
#      11     'Team': ['Luton'],
#    (...)     22     'Red Cards': [0],
#      23     'Yellow Cards': [71]})
#      25 # Read the existing Excel file
# ---> 26 df_existing = pd.read_excel(file_path)
#      28 # Append the new data to the existing DataFrame
#      29 df_new = pd.DataFrame(new_data)
#
# File ~/.local/lib/python3.12/site-packages/pandas/io/excel/_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File ~/.local/lib/python3.12/site-packages/pandas/io/excel/_base.py:1550, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1548     ext = "xls"
#    1549 else:
# -> 1550     ext = inspect_excel_format(
#    1551         content_or_path=path_or_buffer, storage_options=storage_options
#    1552     )
#    1553     if ext is None:
#    1554         raise ValueError(
#    1555             "Excel file format cannot be determined, you must specify "
#    1556             "an engine manually."
#    1557         )
#
# File ~/.local/lib/python3.12/site-packages/pandas/io/excel/_base.py:1402, in inspect_excel_format(content_or_path, storage_options)
#    1399 if isinstance(content_or_path, bytes):
#    1400     content_or_path = BytesIO(content_or_path)
# -> 1402 with get_handle(
#    1403     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1404 ) as handle:
#    1405     stream = handle.handle
#    1406     stream.seek(0)
#
# File ~/.local/lib/python3.12/site-packages/pandas/io/common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)    878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\eviem\\OneDrive\\Documents\\Uni\\Module 2- Digital Maths and Programming\\Uni-Assignment\\Uni-Assignment\\Football Club Stats.zip_unzipped\\Football Club Stats\\Luton Stats.xlsx'

# %%
# This script combines existing Excel files into a single Excel file containing data for different football clubs for the 23/24 and 24/25 Premier league seasons.

import pandas as pd

# List of file paths for the football club stats
def main():
    file_paths = [
        r"C:\Users\eviem\OneDrive\Documents\Uni\Module 2- Digital Maths and Programming\Uni-Assignment\Uni-Assignment\Football Club Stats.zip_unzipped\Football Club Stats\Arsenal Stats.xlsx",
        r"C:\Users\eviem\OneDrive\Documents\Uni\Module 2- Digital Maths and Programming\Uni-Assignment\Uni-Assignment\Football Club Stats.zip_unzipped\Football Club Stats\Aston Villa Stats.xlsx",
        r"C:\Users\eviem\OneDrive\Documents\Uni\Module 2- Digital Maths and Programming\Uni-Assignment\Uni-Assignment\Football Club Stats.zip_unzipped\Football Club Stats\Bournemouth Stats.xlsx",
        r"C:\Users\eviem\OneDrive\Documents\Uni\Module 2- Digital Maths and Programming\Uni-Assignment\Uni-Assignment\Football Club Stats.zip_unzipped\Football Club Stats\Brentford Stats.xlsx",
        r"C:\Users\eviem\OneDrive\Documents\Uni\Module 2- Digital Maths and Programming\Uni-Assignment\Uni-Assignment\Football Club Stats.zip_unzipped\Football Club Stats\Brighton Stats.xlsx",
        r"C:\Users\eviem\OneDrive\Documents\Uni\Module 2- Digital Maths and Programming\Uni-Assignment\Uni-Assignment\Football Club Stats.zip_unzipped\Football Club Stats\Burnley Stats.xlsx",
        r"C:\Users\eviem\OneDrive\Documents\Uni\Module 2- Digital Maths and Programming\Uni-Assignment\Uni-Assignment\Football Club Stats.zip_unzipped\Football Club Stats\Chelsea Stats.xlsx",
        r"C:\Users\eviem\OneDrive\Documents\Uni\Module 2- Digital Maths and Programming\Uni-Assignment\Uni-Assignment\Football Club Stats.zip_unzipped\Football Club Stats\Crystal Palace Stats.xlsx",
        r"C:\Users\eviem\OneDrive\Documents\Uni\Module 2- Digital Maths and Programming\Uni-Assignment\Uni-Assignment\Football Club Stats.zip_unzipped\Football Club Stats\Everton Stats.xlsx",
        r"C:\Users\eviem\OneDrive\Documents\Uni\Module 2- Digital Maths and Programming\Uni-Assignment\Uni-Assignment\Football Club Stats.zip_unzipped\Football Club Stats\Fulham Stats.xlsx",
        r"C:\Users\eviem\OneDrive\Documents\Uni\Module 2- Digital Maths and Programming\Uni-Assignment\Uni-Assignment\Football Club Stats.zip_unzipped\Football Club Stats\Ipswich Stats.xlsx",
        r"C:\Users\eviem\OneDrive\Documents\Uni\Module 2- Digital Maths and Programming\Uni-Assignment\Uni-Assignment\Football Club Stats.zip_unzipped\Football Club Stats\Leicester Stats.xlsx",
        r"C:\Users\eviem\OneDrive\Documents\Uni\Module 2- Digital Maths and Programming\Uni-Assignment\Uni-Assignment\Football Club Stats.zip_unzipped\Football Club Stats\Liverpool Stats.xlsx",
        r"C:\Users\eviem\OneDrive\Documents\Uni\Module 2- Digital Maths and Programming\Uni-Assignment\Uni-Assignment\Football Club Stats.zip_unzipped\Football Club Stats\Luton Stats.xlsx",
        r"C:\Users\eviem\OneDrive\Documents\Uni\Module 2- Digital Maths and Programming\Uni-Assignment\Uni-Assignment\Football Club Stats.zip_unzipped\Football Club Stats\Manchester City Stats.xlsx",
        r"C:\Users\eviem\OneDrive\Documents\Uni\Module 2- Digital Maths and Programming\Uni-Assignment\Uni-Assignment\Football Club Stats.zip_unzipped\Football Club Stats\Manchester United Stats.xlsx",
        r"C:\Users\eviem\OneDrive\Documents\Uni\Module 2- Digital Maths and Programming\Uni-Assignment\Uni-Assignment\Football Club Stats.zip_unzipped\Football Club Stats\Newcastle Stats.xlsx",
        r"C:\Users\eviem\OneDrive\Documents\Uni\Module 2- Digital Maths and Programming\Uni-Assignment\Uni-Assignment\Football Club Stats.zip_unzipped\Football Club Stats\Nottingham Stats.xlsx",
        r"C:\Users\eviem\OneDrive\Documents\Uni\Module 2- Digital Maths and Programming\Uni-Assignment\Uni-Assignment\Football Club Stats.zip_unzipped\Football Club Stats\Sheffield United Stats.xlsx",
        r"C:\Users\eviem\OneDrive\Documents\Uni\Module 2- Digital Maths and Programming\Uni-Assignment\Uni-Assignment\Football Club Stats.zip_unzipped\Football Club Stats\Southampton Stats.xlsx",
        r"C:\Users\eviem\OneDrive\Documents\Uni\Module 2- Digital Maths and Programming\Uni-Assignment\Uni-Assignment\Football Club Stats.zip_unzipped\Football Club Stats\Tottenham Stats.xlsx",
        r"C:\Users\eviem\OneDrive\Documents\Uni\Module 2- Digital Maths and Programming\Uni-Assignment\Uni-Assignment\Football Club Stats.zip_unzipped\Football Club Stats\West Ham Stats.xlsx",
        r"C:\Users\eviem\OneDrive\Documents\Uni\Module 2- Digital Maths and Programming\Uni-Assignment\Uni-Assignment\Football Club Stats.zip_unzipped\Football Club Stats\Wolverhampton Stats.xlsx"]
    
     # Read the first file to start the DataFrame
    df = pd.read_excel(file_paths[0])

    # Loop through the rest and append
    for path in file_paths[1:]:
        df = pd.concat([df, pd.read_excel(path)], ignore_index=True, sort=False)

    # Remove any rows with null values
    df.dropna(inplace=True)

    # Save the combined DataFrame to a new Excel file
    df.to_excel("Combined Football Club Stats.xlsx", index=False)
    
    if __name__ == "__main__":
        main()

# %%
# This script is a user interface for viewing football club stats, league standings and graphs.

import pandas as pd

import matplotlib.pyplot as plt

from colorama import Fore, Style

from tabulate import tabulate

import sys 

# Placeholder functions for displaying stats, standings, and graphs
def display_team_stats(team_name):
    print (f"{team_name} Stats.")
def display_season_stats(team_name, season):
    print(f"Loading stats for {team_name} {season}...")
def display_league_standings():
    print("Showing league standings (function not yet implemented).")
def display_graphs():
    print("Displaying graphs (function not yet implemented).")

# Main function
def main():
   print("Welcome to the Premier League Data Analyser!")
   print("------------------------------")
   print("Main Menu")
   print("Options:")
   print("1. View team stats")
   print("2. View league standings")
   print("3. View graphs")
   print("4. Exit the Premier League Data Analyser")
   
   main_input = input("Enter your choice (1/2/3/4): ").strip()
   # Team Stats Viewer
   if main_input == "1":
       def team_stats_viewer():
           print("------------------------------")
           print(Fore.RED + f"Welcome to the Team Stats Viewer!" + Fore.RESET)
           print("You can view stats for any Premier League team from the 23/24 and 24/25 seasons.")
           print("Please enter the team name you want to view stats for.")
           team_name = input("Enter the team name: ").strip()

           # List of valid team names
           valid_teams = [
               "Arsenal", "Aston Villa", "Bournemouth", "Brentford", "Brighton", "Burnley", "Chelsea", "Crystal Palace",
               "Everton", "Fulham", "Ipswich", "Leicester", "Liverpool", "Luton", "Manchester City", "Manchester United",
               "Newcastle", "Nottingham", "Sheffield United", "Southampton", "Tottenham", "West Ham", "Wolverhampton"
           ]
        
           # Check if the entered team name is valid
           if team_name in valid_teams:
               print("------------------------------")
               print(f"You entered: {Fore.RED}{team_name}{Fore.RESET}")
               print("------------------------------")

               # Define a function to display the team stats season viewer
               def team_stats_season_viewer():
                   # Navigation options for team stats viewer and season selection
                   def navigation_options_team_stats():
                       print("------------------------------")
                       print("Navigation Options:")
                       print("1. Return to Team Stats Viewer")
                       print(f"2. Return to Season Selection for {Fore.RED}{team_name}{Fore.RESET}")
                       print("3. Return to Main Menu")
                       print("4. Exit the Premier League Data Analyser")

                       navigation_input = input("Enter your choice (1/2/3/4): ").strip()
                       # If the user chooses 1- Return to Team Stats Viewer
                       if navigation_input == "1":
                           print("------------------------------")
                           print(Fore.RED + f"Returning to Team Stats Viewer..." + Fore.RESET)
                           return team_stats_viewer()
                          
                       # If the user chooses 2- Return to Season Selection for the team
                       elif navigation_input == "2":
                           print("------------------------------")
                           print(Fore.RED + f"Returning to Season Selection for {team_name}..." + Fore.RESET)
                           print("-------------------------------")
                           return team_stats_season_viewer()
                          
                       # If the user chooses 3- Return to Main Menu
                       elif navigation_input == "3":
                           print("------------------------------")
                           print(Fore.RED +"Returning to Main Menu..." + Fore.RESET)
                           print("-------------------------------")
                           return main()
                          
                       # If the user chooses 4- Exit the Premier League Data Analyser
                       elif navigation_input == "4":
                           print("------------------------------")
                           print(Fore.RED + "Exiting the Premier League Data Analyser. Goodbye!" + Fore.RESET)
                           sys.exit()
                          
                       # If the user enters an invalid choice
                       else:
                           print("------------------------------")
                           print(Fore.RED + "Invalid choice. Please try again." + Fore.RESET)
                           return navigation_options_team_stats()
                       
                   # Load the Combined Football Stats Excel file
                   file_path_combined = "C:\\Users\\eviem\\OneDrive\\Documents\\Uni\\Module 2- Digital Maths and Programming\\Uni-Assignment\\Uni-Assignment\\Combined Football Club Stats.xlsx"
                   try:
                       data = pd.read_excel(file_path_combined)
                   except Exception as e:
                       print(Fore.RED + f"Error loading Excel file: {e}" + Fore.RESET)
                       print("------------------------------")
                       print(Fore.RED + "Returning to Team Stats Viewer..." + Fore.RESET)
                       print("------------------------------")
                       return team_stats_viewer()

                   # Display the season selection menu      
                   print(f"Which season do you want to view stats for {Fore.RED}{team_name}{Fore.RESET}?")
                   print("Options:")
                   print("1. All seasons available on Premier League Data Analyser")
                   print("2. 24/25")
                   print("3. 23/24")
                   print("4. Return to Team Stats Viewer")
                   print("5. Return to Main Menu")
                   print("------------------------------")
                   season_choice = input("Enter your choice (1/2/3/4/5): ").strip()

                   def handle_season_display(season_label, filter_seasons):
                       display_season_stats(Fore.RED + team_name + Style.RESET_ALL, Fore.RED + season_label + Style.RESET_ALL)
                       print("------------------------------")
                       filtered_data = data[(data['Team'] == team_name) & (data['Season'].isin(filter_seasons))]
                       if filtered_data.empty:
                           if len(filter_seasons) == 1:
                               print(Fore.RED + f"No data for {team_name} in the {filter_seasons[0]} season." + Fore.RESET)
                           else:
                               print(Fore.RED + f"No data for {team_name} in the selected seasons." + Fore.RESET)
                               return team_stats_season_viewer()
                       else:
                           filtered_data = filtered_data.reset_index(drop=True)
                           print(tabulate(filtered_data, headers='keys', tablefmt='grid'))
                       print("------------------------------")
                       navigation_options_team_stats()

                   # Handle season choice
                   if season_choice == "1":
                       handle_season_display("All Seasons", ['23/24', '24/25'])  
                   elif season_choice == "2":
                       handle_season_display("24/25 Season", ['24/25'])
                   elif season_choice == "3":
                       handle_season_display("23/24 Season", ['23/24'])
                   elif season_choice == "4":
                       print("------------------------------")
                       print(Fore.RED + "Returning to Team Stats Viewer..." + Fore.RESET)
                       return team_stats_viewer()
                   elif season_choice == "5":
                       print("------------------------------")
                       print(Fore.RED + "Returning to Main Menu..." + Fore.RESET)
                       return main()
                   else:
                       print("------------------------------")
                       print("Invalid choice. Please try again.")
                       return team_stats_season_viewer()

           # If the entered team name is not valid
           else:
               print("------------------------------")
               print(f"Sorry, the Premier League Football Analyser does not have any data for {Fore.RED}{team_name}{Fore.RESET}. Please try again.")
               print("------------------------------")

               # Define a function to show valid team names
               def valid_team_name_options():
                   print("Do you want to see a list of the valid team names?")
                   print("Options:")
                   print("1. Yes")
                   print("2. No")

                   show_valid_teams = input("Enter your choice (1/2): ").strip()
            
                   # If the user chooses to see valid teams
                   if show_valid_teams == "1":
                       print("------------------------------")
                       print(Fore.RED +"You chose Yes." + Fore.RESET)
                       print("------------------------------")
                       print(Fore.RED + "Valid Team Names:" + Fore.RESET)
                          # Print the list of valid teams as a bulleted list
                       for valid_team in valid_teams:
                           print(f"- {valid_team}")
                       print("------------------------------")
                       print(Fore.RED + "Returning to Team Stats Viewer..." + Fore.RESET)
                       return team_stats_viewer() 

                   # If the user chooses to not see valid teams  
                   elif show_valid_teams == "2":
                       print("------------------------------")
                       print(Fore.RED + "You chose No." + Fore.RESET)
                       print("------------------------------")
                       print(Fore.RED + "Returning to Team Stats Viewer..." + Fore.RESET)
                       return team_stats_viewer()
               
                   # If the user enters an invalid choice
                   else:
                       print("------------------------------")
                       print(Fore.RED + "Invalid choice. Please try again." + Fore.RESET)
                       print("------------------------------")
                       return valid_team_name_options()
               
       # End of team_stats_viewer()
       team_stats_viewer()

   # League Standings Viewer
   elif main_input == "2":
       print("------------------------------")
       print(Fore.RED + "Welcome to the League Standings Viewer!" + Fore.RESET)
       print("This feature is not yet implemented.")
         
   # Graphs Viewer
   elif main_input == "3":
       print("------------------------------")
       print(Fore.RED + f"Welcome to the Graph Viewer!" + Fore.RESET)
       print("This feature is not yet implemented.")

   # Exit the Premier League Data Analyser
   elif main_input == "4":
       print("------------------------------")
       print(Fore.RED + "Exiting the Premier League Data Analyser. Goodbye!" + Fore.RESET)
       sys.exit()
   
    # If the user enters an invalid choice
   else:
       print("------------------------------")
       print(Fore.RED + "Invalid choice. Please try again." + Fore.RESET)
       return main()
   


if __name__ == "__main__":
    main()
# Out:
# Welcome to the Premier League Data Analyser!
# ------------------------------
# Main Menu
# Options:
# 1. View team stats
# 2. View league standings
# 3. View graphs
# 4. Exit the Premier League Data Analyser
# ------------------------------
# Welcome to the Team Stats Viewer!
# You can view stats for any Premier League team from the 23/24 and 24/25 seasons.
# Please enter the team name you want to view stats for.
# ------------------------------
# You entered: Liverpool
# ------------------------------

# %%
# This script is a user interface for viewing football club stats, league standings and graphs.

import pandas as pd
import matplotlib.pyplot as plt
from colorama import Fore, Style
from tabulate import tabulate
import sys 

# Placeholder functions for displaying stats, standings, and graphs
def display_team_stats(team_name):
    print (f"{team_name} Stats.")
def display_season_stats(team_name, season):
    print(f"Loading stats for {team_name} {season}...")
def display_league_standings():
    print("Showing league standings (function not yet implemented).")
def display_graphs():
    print("Displaying graphs (function not yet implemented).")

# Team Stats Viewer
def team_stats_viewer():
    print("------------------------------")
    print(Fore.RED + f"Welcome to the Team Stats Viewer!" + Fore.RESET)
    print("You can view stats for any Premier League team from the 23/24 and 24/25 seasons.")
    print("Please enter the team name you want to view stats for.")
    team_name = input("Enter the team name: ").strip()

    # List of valid team names
    valid_teams = [
        "Arsenal", "Aston Villa", "Bournemouth", "Brentford", "Brighton", "Burnley", "Chelsea", "Crystal Palace",
        "Everton", "Fulham", "Ipswich", "Leicester", "Liverpool", "Luton", "Manchester City", "Manchester United",
        "Newcastle", "Nottingham", "Sheffield United", "Southampton", "Tottenham", "West Ham", "Wolverhampton"
    ]

    # Check if the entered team name is valid
    if team_name in valid_teams:
        print("------------------------------")
        print(f"You entered: {Fore.RED}{team_name}{Fore.RESET}")
        print("------------------------------")

        # Define a function to display the team stats season viewer
        def team_stats_season_viewer():
            # Navigation options for team stats viewer and season selection
            def navigation_options_team_stats():
                print("------------------------------")
                print("Navigation Options:")
                print("1. Return to Team Stats Viewer")
                print(f"2. Return to Season Selection for {Fore.RED}{team_name}{Fore.RESET}")
                print("3. Return to Main Menu")
                print("4. Exit the Premier League Data Analyser")

                navigation_input = input("Enter your choice (1/2/3/4): ").strip()
                if navigation_input == "1":
                    print("------------------------------")
                    print(Fore.RED + f"Returning to Team Stats Viewer..." + Fore.RESET)
                    return team_stats_viewer()
                elif navigation_input == "2":
                    print("------------------------------")
                    print(Fore.RED + f"Returning to Season Selection for {team_name}..." + Fore.RESET)
                    return team_stats_season_viewer()
                elif navigation_input == "3":
                    print("------------------------------")
                    print(Fore.RED +"Returning to Main Menu..." + Fore.RESET)
                    return
                elif navigation_input == "4":
                    print("------------------------------")
                    print(Fore.RED + "Exiting the Premier League Data Analyser. Goodbye!" + Fore.RESET)
                    sys.exit()
                else:
                    print("------------------------------")
                    print(Fore.RED + "Invalid choice. Please try again." + Fore.RESET)
                    return navigation_options_team_stats()
                
            # Load the Combined Football Stats Excel file
            file_path = "C:\\Users\\eviem\\OneDrive\\Documents\\Uni\\Module 2- Digital Maths and Programming\\Uni-Assignment\\Uni-Assignment\\Combined Football Club Stats.xlsx"
            try:
                data = pd.read_excel(file_path)
            except Exception as e:
                print(Fore.RED + f"Error loading Excel file: {e}" + Fore.RESET)
                print(Fore.RED + "Returning to Team Stats Viewer..." + Fore.RESET)
                return team_stats_viewer()

            print(f"Which season do you want to view stats for {Fore.RED}{team_name}{Fore.RESET}?")
            print("Options:")
            print("1. All seasons available on Premier League Data Analyser")
            print("2. 24/25")
            print("3. 23/24")
            print("4. Return to Team Stats Viewer")
            print("5. Return to Main Menu")
            print("------------------------------")
            season_choice = input("Enter your choice (1/2/3/4/5): ").strip()

            def handle_season_display(season_label, filter_seasons):
                display_season_stats(Fore.RED + team_name + Style.RESET_ALL, Fore.RED + season_label + Style.RESET_ALL)
                print("------------------------------")
                filtered_data = data[(data['Team'] == team_name) & (data['Season'].isin(filter_seasons))]
                if filtered_data.empty:
                    print(Fore.RED + f"No data for {team_name} in the selected season(s)." + Fore.RESET)
                    return team_stats_season_viewer()
                else:
                    filtered_data = filtered_data.reset_index(drop=True)
                    print(tabulate(filtered_data, headers='keys', tablefmt='grid'))
                print("------------------------------")
                navigation_options_team_stats()

            if season_choice == "1":
                handle_season_display("All Seasons", ['23/24', '24/25'])  
            elif season_choice == "2":
                handle_season_display("24/25 Season", ['24/25'])
            elif season_choice == "3":
                handle_season_display("23/24 Season", ['23/24'])
            elif season_choice == "4":
                print(Fore.RED + "Returning to Team Stats Viewer..." + Fore.RESET)
                return team_stats_viewer()
            elif season_choice == "5":
                print(Fore.RED + "Returning to Main Menu..." + Fore.RESET)
                return
            else:
                print("Invalid choice. Please try again.")
                return team_stats_season_viewer()

        team_stats_season_viewer()

    else:
        print("------------------------------")
        print(f"Sorry, the Premier League Football Analyser does not have any data for {Fore.RED}{team_name}{Fore.RESET}. Please try again.")
        print("------------------------------")

        # Define a function to show valid team names
        def valid_team_name_options():
            print("Do you want to see a list of the valid team names?")
            print("Options:")
            print("1. Yes")
            print("2. No")

            show_valid_teams = input("Enter your choice (1/2): ").strip()
            if show_valid_teams == "1":
                print("------------------------------")
                print(Fore.RED + "Valid Team Names:" + Fore.RESET)
                for valid_team in valid_teams:
                    print(f"- {valid_team}")
                print(Fore.RED + "Returning to Team Stats Viewer..." + Fore.RESET)
                return team_stats_viewer()
            elif show_valid_teams == "2":
                print(Fore.RED + "Returning to Team Stats Viewer..." + Fore.RESET)
                return team_stats_viewer()
            else:
                print(Fore.RED + "Invalid choice. Please try again." + Fore.RESET)
                return valid_team_name_options()

        valid_team_name_options()


# Main function with loop to avoid recursion
def main():
    while True:
        print("Welcome to the Premier League Data Analyser!")
        print("------------------------------")
        print("Main Menu")
        print("Options:")
        print("1. View team stats")
        print("2. View league standings")
        print("3. View graphs")
        print("4. Exit the Premier League Data Analyser")
        
        main_input = input("Enter your choice (1/2/3/4): ").strip()
        
        if main_input == "1":
            team_stats_viewer()
        elif main_input == "2":
            print(Fore.RED + "Welcome to the League Standings Viewer!" + Fore.RESET)
            print("This feature is not yet implemented.")
        elif main_input == "3":
            print(Fore.RED + "Welcome to the Graph Viewer!" + Fore.RESET)
            print("This feature is not yet implemented.")
        elif main_input == "4":
            print(Fore.RED + "Exiting the Premier League Data Analyser. Goodbye!" + Fore.RESET)
            sys.exit()
        else:
            print(Fore.RED + "Invalid choice. Please try again." + Fore.RESET)

if __name__ == "__main__":
    main()
